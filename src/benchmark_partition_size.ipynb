# %%
import time
import argparse
import math
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, size, length

from sentiment_analysis.config import logger
from sentiment_analysis.load import load_amazon_reviews, load_model
import sentiment_analysis.process as process
from sentiment_analysis.utils import run_command

# %%
target_mb_sizes = [2, 4, 8]
sample_ratio = 0.1
input_file, output_dir = '/Subscription_Boxes.jsonl', '/analysis_outputs'
results = []

# %%
spark = SparkSession.builder \
        .appName("SentimentAnalysisBenchmark") \
        .getOrCreate()

# %%
hadoop_conf = sc._jsc.hadoopConfiguration()
fs = sc._jvm.org.apache.hadoop.fs.FileSystem.get(hadoop_conf)

# Define the HDFS path
path = sc._jvm.org.apache.hadoop.fs.Path(input_file)

# Get file status and size
file_status = fs.getFileStatus(path)
file_size_bytes = file_status.getLen()  # size in bytes
file_size_mb = file_size_bytes / (1024 * 1024)

print(f"File size: {file_size_bytes} bytes ({file_size_mb:.2f} MB)")
# Out:
# File size: 8953020 bytes (8.54 MB)

# %%
total_cores = sc.defaultParallelism
task_cpus = int(spark.conf.get("spark.task.cpus", "1"))
min_partitions = total_cores // task_cpus
logger.info(f"Using {min_partitions} min partitions")
# Out:
# 2025-04-10 11:27:25,144 - INFO - Using 16 min partitions

# %%
for target_mb in target_mb_sizes:
    logger.info(f"Testing with target partition size of {target_mb} MB...")
    
    # Calculate number of partitions
    target_bytes = target_mb * 1024 * 1024
    num_partitions = max(1, math.ceil(file_size_bytes / target_bytes))
    
    logger.info(f"Using {num_partitions} partitions for {target_mb} MB target size")
# Out:
# 2025-04-10 11:27:29,665 - INFO - Testing with target partition size of 2 MB...
# 2025-04-10 11:27:29,667 - INFO - Using 5 partitions for 2 MB target size
# 2025-04-10 11:27:29,670 - INFO - Testing with target partition size of 4 MB...
# 2025-04-10 11:27:29,672 - INFO - Using 3 partitions for 4 MB target size
# 2025-04-10 11:27:29,673 - INFO - Testing with target partition size of 8 MB...
# 2025-04-10 11:27:29,675 - INFO - Using 2 partitions for 8 MB target size

# %%
# Load the dataset once
reviews_df_original = load_amazon_reviews(spark, input_file, sample_ratio)

# Cache the original dataframe to improve performance
reviews_df_original.cache()

# Count total reviews and get estimated size per review
total_reviews = reviews_df_original.count()

# Estimate average review size by sampling
sample_df = reviews_df_original.sample(fraction=min(0.1, 1000.0/total_reviews))
sample_df = sample_df.withColumn("text_length", length(col("text")))

# Get average review text length from the full dataset
reviews_df_with_length = reviews_df_original.withColumn("text_length", length(col("text")))
avg_stats = reviews_df_with_length.agg({"text_length": "avg"}).collect()[0]
avg_text_length = avg_stats["avg(text_length)"]

# Estimate bytes per review (rough approximation including overhead)
# Text is UTF-8 so ~1-4 bytes per character + metadata
estimated_bytes_per_review = avg_text_length * 2 + 200  # Rough estimate

logger.info(f"Total reviews: {total_reviews:,}")
logger.info(f"Estimated average review size: {estimated_bytes_per_review} bytes")

if not process.bc_model:
    # Load model and tokenizer once
    tokenizer, model = load_model()
    # Broadcast model and tokenizer to all workers
    process.bc_tokenizer = spark.sparkContext.broadcast(tokenizer)
    process.bc_model = spark.sparkContext.broadcast(model)
# Out:
# 25/04/10 11:27:30 WARN CacheManager: Asked to cache already cached data.
# 25/04/10 11:27:30 WARN CacheManager: Asked to cache already cached data.
# 2025-04-10 11:27:30,832 - INFO - Total reviews: 1,686
# 2025-04-10 11:27:30,833 - INFO - Estimated average review size: 700.2336892052194 bytes

# %%
total_size = reviews_df_original.rdd.map(lambda x: len(str(x))).sum()
file_size_mb = total_size / (1024 * 1024)
print(f"File size: {total_size} bytes ({file_size_mb:.2f} MB)")
# Out:
# File size: 662423 bytes (0.63 MB)

# %%
target_mb = 8
logger.info(f"Testing with target partition size of {target_mb} MB...")
    
# Calculate target reviews per partition
target_bytes = target_mb * 1024 * 1024
print(f"target_bytes {target_bytes}") 
reviews_per_partition = max(1, int(target_bytes / estimated_bytes_per_review))

# Calculate number of partitions
num_partitions = max(1, int(total_reviews / reviews_per_partition))

logger.info(f"Using {num_partitions} partitions for {target_mb} MB target size")
logger.info(f"Estimated {reviews_per_partition} reviews per partition")
# Out:
# 2025-04-10 11:27:33,403 - INFO - Testing with target partition size of 8 MB...
# 2025-04-10 11:27:33,407 - INFO - Using 1 partitions for 8 MB target size
# 2025-04-10 11:27:33,409 - INFO - Estimated 11979 reviews per partition
# target_bytes 8388608

# %%
for target_mb in target_mb_sizes:
    logger.info(f"Testing with target partition size of {target_mb} MB...")
    
    # Calculate number of partitions
    target_bytes = target_mb * 1024 * 1024
    num_partitions = max(1, math.ceil(file_size_bytes / target_bytes))
    
    logger.info(f"Using {num_partitions} partitions for {target_mb} MB target size")
    
    # Record start time
    start_time = time.time()
    
    # Create a fresh copy of the dataframe for this test
    reviews_df = reviews_df_original
    
    # Repartition the DataFrame to target partition count
    reviews_df = reviews_df.repartition(num_partitions)
    
    # Process time for sentiment analysis
    process_start_time = time.time()
    
    # Run sentiment analysis
    sentiment_results_df = reviews_df.withColumn(
        "result",
        process.batch_sentiment_analysis(reviews_df["text"]),
    )
    
    # Flatten the result column
    sentiment_results_df = sentiment_results_df.select(
        col("asin"),
        col("user_id"),
        col("result.review_text"),
        col("result.sentiment"),
        col("result.score"),
    )
    
    # Force execution with count action
    result_count = sentiment_results_df.count()
    
    # Write results to parquet
    output_path = f"{output_dir}/partition_size_{target_mb}MB"
    
    process_start_time = time.time()
    sentiment_results_df.write.option("header", "true").mode("overwrite").csv(output_path)
    process_time = time.time() - process_start_time
    
    # Total time
    total_time = time.time() - start_time
    
    # Actual partition stats
    actual_partitions = sentiment_results_df.rdd.getNumPartitions()
    actual_reviews_per_partition = total_reviews / actual_partitions
    
    # Store results
    results.append({
        "target_mb": target_mb,
        "num_partitions": actual_partitions,
        "reviews_per_partition": actual_reviews_per_partition,
        "total_reviews": total_reviews,
        "result_count": result_count,
        "process_time": process_time,
        "total_time": total_time,
        "throughput": total_reviews / process_time
    })
    
    # Unpersist the result dataframe to free up memory
    sentiment_results_df.unpersist(blocking=True)
    
    logger.info(f"Completed benchmark with target partition size {target_mb} MB:")
    logger.info(f"  Total reviews: {total_reviews}")
    logger.info(f"  Actual partitions: {actual_partitions}")
    logger.info(f"  Process Time: {process_time:.2f} seconds")
    logger.info(f"  Total Time: {total_time:.2f} seconds")
    logger.info(f"  Processing Throughput: {total_reviews / process_time:.2f} reviews/second")
# Out:
# 2025-04-09 15:37:54,728 - INFO - Testing with target partition size of 2 MB...
# 2025-04-09 15:37:54,730 - INFO - Using 5 partitions for 2 MB target size
# 2025-04-09 15:38:03,349 - INFO - Processing 3244 reviews...         (0 + 4) / 5]
# 2025-04-09 15:38:03,391 - INFO - Processing 3244 reviews...
# 2025-04-09 15:38:03,454 - INFO - Processing 3241 reviews...
# 2025-04-09 15:38:03,513 - INFO - Processing 3243 reviews...
# 2025-04-09 15:48:19,789 - INFO - Done processing 3243 reviews..     (0 + 4) / 5]
# 2025-04-09 15:48:20,222 - INFO - Processing 3244 reviews...         (1 + 4) / 5]
# 2025-04-09 15:48:21,162 - INFO - Done processing 3241 reviews..
# 2025-04-09 15:48:23,799 - INFO - Done processing 3244 reviews..     (2 + 3) / 5]
# 2025-04-09 15:48:25,662 - INFO - Done processing 3244 reviews..     (3 + 2) / 5]
# 2025-04-09 15:58:19,510 - INFO - Done processing 3244 reviews..     (4 + 1) / 5]
# 2025-04-09 15:58:20,036 - INFO - Completed benchmark with target partition size 2 MB:
# 2025-04-09 15:58:20,037 - INFO -   Total reviews: 16216
# 2025-04-09 15:58:20,037 - INFO -   Actual partitions: 5
# 2025-04-09 15:58:20,038 - INFO -   Process Time: 1224.58 seconds
# 2025-04-09 15:58:20,038 - INFO -   Total Time: 1225.08 seconds
# 2025-04-09 15:58:20,039 - INFO -   Processing Throughput: 13.24 reviews/second
# 2025-04-09 15:58:20,039 - INFO - Testing with target partition size of 4 MB...
# 2025-04-09 15:58:20,040 - INFO - Using 3 partitions for 4 MB target size
# 2025-04-09 15:58:20,508 - INFO - Processing 5406 reviews...
# 2025-04-09 15:58:25,163 - INFO - Processing 5405 reviews...         (0 + 3) / 3]
# 2025-04-09 15:58:25,953 - INFO - Processing 5405 reviews...
# 2025-04-09 16:15:35,189 - INFO - Done processing 5405 reviews..     (0 + 3) / 3]
# 2025-04-09 16:15:40,608 - INFO - Done processing 5406 reviews..     (1 + 2) / 3]
# 2025-04-09 16:16:03,989 - INFO - Done processing 5405 reviews..     (2 + 1) / 3]
# 2025-04-09 16:16:04,376 - INFO - Completed benchmark with target partition size 4 MB:
# 2025-04-09 16:16:04,376 - INFO -   Total reviews: 16216
# 2025-04-09 16:16:04,378 - INFO -   Actual partitions: 3
# 2025-04-09 16:16:04,379 - INFO -   Process Time: 1063.96 seconds
# 2025-04-09 16:16:04,380 - INFO -   Total Time: 1064.14 seconds
# 2025-04-09 16:16:04,380 - INFO -   Processing Throughput: 15.24 reviews/second
# 2025-04-09 16:16:04,381 - INFO - Testing with target partition size of 8 MB...
# 2025-04-09 16:16:04,382 - INFO - Using 2 partitions for 8 MB target size
# 2025-04-09 16:16:04,774 - INFO - Processing 8108 reviews...
# 2025-04-09 16:16:04,829 - INFO - Processing 8108 reviews...
# 2025-04-09 16:41:07,867 - INFO - Done processing 8108 reviews..     (0 + 2) / 2]
# 2025-04-09 16:41:18,231 - INFO - Done processing 8108 reviews..     (1 + 1) / 2]
# 2025-04-09 16:41:18,613 - INFO - Completed benchmark with target partition size 8 MB:
# 2025-04-09 16:41:18,614 - INFO -   Total reviews: 16216
# 2025-04-09 16:41:18,616 - INFO -   Actual partitions: 2
# 2025-04-09 16:41:18,617 - INFO -   Process Time: 1513.88 seconds
# 2025-04-09 16:41:18,618 - INFO -   Total Time: 1514.02 seconds
# 2025-04-09 16:41:18,619 - INFO -   Processing Throughput: 10.71 reviews/second

# %%
output_dir = os.getcwd()
Path(output_dir).mkdir(parents=True, exist_ok=True)
results_df = pd.DataFrame(results)
results_df.to_csv(f"{output_dir}/partition_size_benchmark_results.csv", index=False)

# Create a summary report
with open(f"{output_dir}/benchmark_summary.txt", 'w') as f:
    f.write("Spark Partition Size Benchmark Summary\n")
    f.write("=====================================\n\n")
    
    # Find optimal partition size based on throughput
    optimal_idx = results_df['throughput'].idxmax()
    optimal_size = results_df.iloc[optimal_idx]['target_mb']
    optimal_partitions = results_df.iloc[optimal_idx]['num_partitions']
    
    f.write(f"Total reviews processed: {results_df.iloc[0]['total_reviews']}\n")
    f.write(f"Optimal target partition size: {optimal_size} MB\n")
    f.write(f"Optimal number of partitions: {optimal_partitions}\n\n")
    
    f.write("Detailed Results:\n")
    f.write("-----------------\n")
    for _, row in results_df.iterrows():
        f.write(f"Target Partition Size: {row['target_mb']} MB\n")
        f.write(f"  Actual Partitions: {int(row['num_partitions'])}\n")
        f.write(f"  Reviews per partition: {int(row['reviews_per_partition'])}\n")
        f.write(f"  Process Time: {row['process_time']:.2f} seconds\n")
        f.write(f"  Total Time: {row['total_time']:.2f} seconds\n")
        f.write(f"  Throughput: {row['throughput']:.2f} reviews/second\n\n")

# %%
# Create output directory if it doesn't exist
output_dir = os.getcwd()
Path(output_dir).mkdir(parents=True, exist_ok=True)

# Set style
plt.style.use('ggplot')

# Figure 1: Total Time vs Partition Size (MB)
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_mb'], results_df['total_time'], 'o-', linewidth=2)
plt.title('Total Execution Time vs Partition Size')
plt.xlabel('Target Partition Size (MB)')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/total_time_vs_partition_size.png")

# Figure 2: Process Time vs Partition Size (MB)
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_mb'], results_df['process_time'], 'o-', linewidth=2)
plt.title('Processing Time vs Partition Size')
plt.xlabel('Target Partition Size (MB)')
plt.ylabel('Time (seconds)')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/process_time_vs_partition_size.png")

# Figure 3: Throughput vs Partition Size (MB)
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_mb'], results_df['throughput'], 'o-', linewidth=2)
plt.title('Throughput vs Partition Size')
plt.xlabel('Target Partition Size (MB)')
plt.ylabel('Throughput (reviews/second)')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/throughput_vs_partition_size.png")

# Figure 4: Time Breakdown
plt.figure(figsize=(12, 6))
width = 0.35
ind = np.arange(len(results_df))

plt.bar(ind, results_df['process_time'], width, label='Process Time')

plt.xlabel('Target Partition Size (MB)')
plt.ylabel('Time (seconds)')
plt.title('Time Breakdown by Partition Size')
plt.xticks(ind, results_df['target_mb'])
plt.legend()
plt.tight_layout()
plt.savefig(f"{output_dir}/time_breakdown.png")

# Figure 5: Number of Partitions vs Target Size
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_mb'], results_df['num_partitions'], 'o-', linewidth=2)
plt.title('Number of Partitions vs Target Partition Size')
plt.xlabel('Target Partition Size (MB)')
plt.ylabel('Number of Partitions')
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/partitions_vs_size.png")

plt.close('all')

# %%
# Get the executor memory status
executor_memory_status = sc.getExecutorMemoryStatus()

# Count the number of executors
num_executors = len(executor_memory_status)

print(f"Number of executors: {num_executors}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Get the executor memory status
# ----> 2 executor_memory_status = sc.getExecutorMemoryStatus()
#       4 # Count the number of executors
#       5 num_executors = len(executor_memory_status)
#
# AttributeError: 'SparkContext' object has no attribute 'getExecutorMemoryStatus'

# %%
import torch
torch.set_num_threads(1)
torch.set_num_interop_threads(1)

# %%
print(torch.get_num_threads())
print(torch.get_num_interop_threads())
# Out:
# 1
# 1

# %%
target_partitions_counts = [2,3,4,6,8,10,12,16,32,64,128]
results = []
for num_partitions in target_partitions_counts:
    logger.info(f"Testing with target partition count of {num_partitions}...")
    
    logger.info(f"Using {num_partitions} partitions")
    
    # Record start time
    start_time = time.time()
    
    # Create a fresh copy of the dataframe for this test
    reviews_df = reviews_df_original
    
    # Repartition the DataFrame to target partition count
    reviews_df = reviews_df.repartition(num_partitions)
    
    # Process time for sentiment analysis
    process_start_time = time.time()
    
    # Run sentiment analysis
    sentiment_results_df = reviews_df.withColumn(
        "result",
        process.batch_sentiment_analysis(reviews_df["text"]),
    )
    
    # Flatten the result column
    sentiment_results_df = sentiment_results_df.select(
        col("asin"),
        col("user_id"),
        col("result.review_text"),
        col("result.sentiment"),
        col("result.score"),
    )
    
    result_count = sentiment_results_df.count()
    
    # Write results to csv
    output_path = f"{output_dir}/partition_count_{num_partitions}"
    
    process_start_time = time.time()
    sentiment_results_df.write.option("header", "true").mode("overwrite").csv(output_path)
    process_time = time.time() - process_start_time
    
    # Total time
    total_time = time.time() - start_time
    
    # Actual partition stats
    actual_partitions = sentiment_results_df.rdd.getNumPartitions()
    actual_reviews_per_partition = total_reviews / actual_partitions
    
    # Store results
    results.append({
        "target_num_partitions": num_partitions,
        "actual_partitions": actual_partitions,
        "reviews_per_partition": actual_reviews_per_partition,
        "total_reviews": total_reviews,
        "result_count": result_count,
        "process_time": process_time,
        "total_time": total_time,
        "throughput": total_reviews / process_time
    })
    
    # Unpersist the result dataframe to free up memory
    sentiment_results_df.unpersist(blocking=True)
    
    logger.info(f"Completed benchmark with target partition count {num_partitions}:")
    logger.info(f"  Total reviews: {total_reviews}")
    logger.info(f"  Actual partitions: {actual_partitions}")
    logger.info(f"  Process Time: {process_time:.2f} seconds")
    logger.info(f"  Total Time: {total_time:.2f} seconds")
    logger.info(f"  Processing Throughput: {total_reviews / process_time:.2f} reviews/second")
# Out:
# 2025-04-09 18:37:23,557 - INFO - Testing with target partition count of 2...
# 2025-04-09 18:37:23,560 - INFO - Using 2 partitions
# 2025-04-09 18:37:29,216 - INFO - Processing 843 reviews...          (0 + 2) / 2]
# 2025-04-09 18:37:29,509 - INFO - Processing 843 reviews...
# 2025-04-09 18:40:07,988 - INFO - Done processing 843 reviews..      (0 + 2) / 2]
# 2025-04-09 18:40:09,160 - INFO - Done processing 843 reviews..      (1 + 1) / 2]
# 2025-04-09 18:40:09,336 - INFO - Completed benchmark with target partition count 2:
# 2025-04-09 18:40:09,338 - INFO -   Total reviews: 1686
# 2025-04-09 18:40:09,340 - INFO -   Actual partitions: 2
# 2025-04-09 18:40:09,341 - INFO -   Process Time: 165.59 seconds
# 2025-04-09 18:40:09,342 - INFO -   Total Time: 165.71 seconds
# 2025-04-09 18:40:09,343 - INFO -   Processing Throughput: 10.18 reviews/second
# 2025-04-09 18:40:09,344 - INFO - Testing with target partition count of 3...
# 2025-04-09 18:40:09,345 - INFO - Using 3 partitions
# 2025-04-09 18:40:09,557 - INFO - Processing 562 reviews...
# 2025-04-09 18:40:09,574 - INFO - Processing 562 reviews...
# 2025-04-09 18:40:14,368 - INFO - Processing 562 reviews...          (0 + 3) / 3]
# 2025-04-09 18:41:57,696 - INFO - Done processing 562 reviews..      (0 + 3) / 3]
# 2025-04-09 18:41:59,049 - INFO - Done processing 562 reviews..      (1 + 2) / 3]
# 2025-04-09 18:42:03,075 - INFO - Done processing 562 reviews..      (2 + 1) / 3]
# 2025-04-09 18:42:03,253 - INFO - Completed benchmark with target partition count 3:
# 2025-04-09 18:42:03,254 - INFO -   Total reviews: 1686
# 2025-04-09 18:42:03,254 - INFO -   Actual partitions: 3
# 2025-04-09 18:42:03,255 - INFO -   Process Time: 113.79 seconds
# 2025-04-09 18:42:03,256 - INFO -   Total Time: 113.87 seconds
# 2025-04-09 18:42:03,256 - INFO -   Processing Throughput: 14.82 reviews/second
# 2025-04-09 18:42:03,257 - INFO - Testing with target partition count of 4...
# 2025-04-09 18:42:03,258 - INFO - Using 4 partitions
# 2025-04-09 18:42:03,496 - INFO - Processing 423 reviews...
# 2025-04-09 18:42:03,521 - INFO - Processing 420 reviews...
# 2025-04-09 18:42:03,605 - INFO - Processing 421 reviews...
# 2025-04-09 18:42:09,098 - INFO - Processing 422 reviews...          (0 + 4) / 4]
# 2025-04-09 18:43:24,479 - INFO - Done processing 423 reviews..      (0 + 4) / 4]
# 2025-04-09 18:43:25,054 - INFO - Done processing 420 reviews..      (1 + 3) / 4]
# 2025-04-09 18:43:26,782 - INFO - Done processing 421 reviews..      (2 + 2) / 4]
# 2025-04-09 18:43:30,187 - INFO - Done processing 422 reviews..      (3 + 1) / 4]
# 2025-04-09 18:43:30,400 - INFO - Completed benchmark with target partition count 4:
# 2025-04-09 18:43:30,401 - INFO -   Total reviews: 1686
# 2025-04-09 18:43:30,402 - INFO -   Actual partitions: 4
# 2025-04-09 18:43:30,403 - INFO -   Process Time: 87.00 seconds
# 2025-04-09 18:43:30,405 - INFO -   Total Time: 87.08 seconds
# 2025-04-09 18:43:30,406 - INFO -   Processing Throughput: 19.38 reviews/second
# 2025-04-09 18:43:30,406 - INFO - Testing with target partition count of 6...
# 2025-04-09 18:43:30,407 - INFO - Using 6 partitions
# 2025-04-09 18:43:30,666 - INFO - Processing 281 reviews...
# 2025-04-09 18:43:30,670 - INFO - Processing 281 reviews...
# 2025-04-09 18:43:30,703 - INFO - Processing 281 reviews...
# 2025-04-09 18:43:30,710 - INFO - Processing 281 reviews...
# 2025-04-09 18:44:24,559 - INFO - Done processing 281 reviews..      (0 + 4) / 6]
# 2025-04-09 18:44:24,684 - INFO - Done processing 281 reviews..
# 2025-04-09 18:44:24,690 - INFO - Processing 281 reviews...
# 2025-04-09 18:44:24,766 - INFO - Processing 281 reviews...          (1 + 4) / 6]
# 2025-04-09 18:44:25,530 - INFO - Done processing 281 reviews..      (2 + 4) / 6]
# 2025-04-09 18:44:26,538 - INFO - Done processing 281 reviews..      (3 + 3) / 6]
# 2025-04-09 18:45:16,510 - INFO - Done processing 281 reviews..      (4 + 2) / 6]
# 2025-04-09 18:45:16,664 - INFO - Done processing 281 reviews..
# 2025-04-09 18:45:16,891 - INFO - Completed benchmark with target partition count 6:
# 2025-04-09 18:45:16,892 - INFO -   Total reviews: 1686
# 2025-04-09 18:45:16,893 - INFO -   Actual partitions: 6
# 2025-04-09 18:45:16,894 - INFO -   Process Time: 106.32 seconds
# 2025-04-09 18:45:16,895 - INFO -   Total Time: 106.43 seconds
# 2025-04-09 18:45:16,895 - INFO -   Processing Throughput: 15.86 reviews/second
# 2025-04-09 18:45:16,896 - INFO - Testing with target partition count of 8...
# 2025-04-09 18:45:16,897 - INFO - Using 8 partitions
# 2025-04-09 18:45:17,151 - INFO - Processing 211 reviews...
# 2025-04-09 18:45:17,152 - INFO - Processing 211 reviews...
# 2025-04-09 18:45:17,170 - INFO - Processing 211 reviews...
# 2025-04-09 18:45:17,214 - INFO - Processing 213 reviews...
# 2025-04-09 18:45:57,571 - INFO - Done processing 211 reviews..      (0 + 4) / 8]
# 2025-04-09 18:45:57,703 - INFO - Processing 210 reviews...
# 2025-04-09 18:45:58,092 - INFO - Done processing 211 reviews..      (1 + 4) / 8]
# 2025-04-09 18:45:58,200 - INFO - Processing 210 reviews...          (2 + 4) / 8]
# 2025-04-09 18:45:58,781 - INFO - Done processing 211 reviews..
# 2025-04-09 18:45:58,875 - INFO - Processing 210 reviews...
# 2025-04-09 18:45:59,895 - INFO - Done processing 213 reviews..      (3 + 4) / 8]
# 2025-04-09 18:46:00,003 - INFO - Processing 210 reviews...          (4 + 4) / 8]
# 2025-04-09 18:46:37,846 - INFO - Done processing 210 reviews..
# 2025-04-09 18:46:38,190 - INFO - Done processing 210 reviews..      (5 + 3) / 8]
# 2025-04-09 18:46:39,394 - INFO - Done processing 210 reviews..      (6 + 2) / 8]
# 2025-04-09 18:46:40,855 - INFO - Done processing 210 reviews..      (7 + 1) / 8]
# 2025-04-09 18:46:41,104 - INFO - Completed benchmark with target partition count 8:
# 2025-04-09 18:46:41,105 - INFO -   Total reviews: 1686
# 2025-04-09 18:46:41,107 - INFO -   Actual partitions: 8
# 2025-04-09 18:46:41,108 - INFO -   Process Time: 84.05 seconds
# 2025-04-09 18:46:41,108 - INFO -   Total Time: 84.15 seconds
# 2025-04-09 18:46:41,109 - INFO -   Processing Throughput: 20.06 reviews/second
# 2025-04-09 18:46:41,110 - INFO - Testing with target partition count of 10...
# 2025-04-09 18:46:41,110 - INFO - Using 10 partitions
# 2025-04-09 18:46:41,316 - INFO - Processing 169 reviews...
# 2025-04-09 18:46:41,319 - INFO - Processing 169 reviews...
# 2025-04-09 18:46:41,320 - INFO - Processing 168 reviews...
# 2025-04-09 18:46:41,351 - INFO - Processing 169 reviews...
# 2025-04-09 18:47:14,156 - INFO - Done processing 169 reviews..     (0 + 4) / 10]
# 2025-04-09 18:47:14,295 - INFO - Processing 169 reviews...
# 2025-04-09 18:47:14,408 - INFO - Done processing 168 reviews..
# 2025-04-09 18:47:14,558 - INFO - Processing 169 reviews...         (1 + 4) / 10]
# 2025-04-09 18:47:14,599 - INFO - Done processing 169 reviews..
# 2025-04-09 18:47:14,734 - INFO - Processing 168 reviews...         (2 + 4) / 10]
# 2025-04-09 18:47:15,051 - INFO - Done processing 169 reviews..     (3 + 4) / 10]
# 2025-04-09 18:47:15,165 - INFO - Processing 168 reviews...
# 2025-04-09 18:47:46,623 - INFO - Done processing 168 reviews..     (4 + 4) / 10]
# 2025-04-09 18:47:46,746 - INFO - Done processing 169 reviews..
# 2025-04-09 18:47:46,770 - INFO - Processing 168 reviews...
# 2025-04-09 18:47:46,851 - INFO - Processing 169 reviews...
# 2025-04-09 18:47:47,196 - INFO - Done processing 169 reviews..     (6 + 4) / 10]
# 2025-04-09 18:47:47,367 - INFO - Done processing 168 reviews..
# 2025-04-09 18:48:18,146 - INFO - Done processing 168 reviews..     (8 + 2) / 10]
# 2025-04-09 18:48:18,312 - INFO - Done processing 169 reviews..
# 2025-04-09 18:48:18,548 - INFO - Completed benchmark with target partition count 10:
# 2025-04-09 18:48:18,549 - INFO -   Total reviews: 1686
# 2025-04-09 18:48:18,550 - INFO -   Actual partitions: 10
# 2025-04-09 18:48:18,550 - INFO -   Process Time: 97.29 seconds
# 2025-04-09 18:48:18,550 - INFO -   Total Time: 97.38 seconds
# 2025-04-09 18:48:18,551 - INFO -   Processing Throughput: 17.33 reviews/second
# 2025-04-09 18:48:18,551 - INFO - Testing with target partition count of 12...
# 2025-04-09 18:48:18,552 - INFO - Using 12 partitions
# 2025-04-09 18:48:18,798 - INFO - Processing 141 reviews...
# 2025-04-09 18:48:18,807 - INFO - Processing 141 reviews...
# 2025-04-09 18:48:18,808 - INFO - Processing 141 reviews...
# 2025-04-09 18:48:18,810 - INFO - Processing 140 reviews...
# 2025-04-09 18:48:45,633 - INFO - Done processing 141 reviews..     (0 + 4) / 12]
# 2025-04-09 18:48:45,759 - INFO - Processing 140 reviews...         (1 + 4) / 12]
# 2025-04-09 18:48:46,307 - INFO - Done processing 141 reviews..
# 2025-04-09 18:48:46,403 - INFO - Processing 140 reviews...
# 2025-04-09 18:48:46,490 - INFO - Done processing 140 reviews..
# 2025-04-09 18:48:46,577 - INFO - Processing 140 reviews...         (2 + 4) / 12]
# 2025-04-09 18:48:47,223 - INFO - Done processing 141 reviews..     (3 + 4) / 12]
# 2025-04-09 18:48:47,359 - INFO - Processing 140 reviews...         (4 + 4) / 12]
# 2025-04-09 18:49:12,663 - INFO - Done processing 140 reviews..
# 2025-04-09 18:49:12,805 - INFO - Processing 140 reviews...
# 2025-04-09 18:49:13,282 - INFO - Done processing 140 reviews..     (5 + 4) / 12]
# 2025-04-09 18:49:13,398 - INFO - Processing 141 reviews...
# 2025-04-09 18:49:13,748 - INFO - Done processing 140 reviews..     (6 + 4) / 12]
# 2025-04-09 18:49:13,909 - INFO - Processing 141 reviews...
# 2025-04-09 18:49:14,525 - INFO - Done processing 140 reviews..     (7 + 4) / 12]
# 2025-04-09 18:49:14,616 - INFO - Processing 141 reviews...
# 2025-04-09 18:49:39,372 - INFO - Done processing 140 reviews..     (8 + 4) / 12]
# 2025-04-09 18:49:40,677 - INFO - Done processing 141 reviews..     (9 + 3) / 12]
# 2025-04-09 18:49:40,924 - INFO - Done processing 141 reviews..    (10 + 2) / 12]
# 2025-04-09 18:49:41,808 - INFO - Done processing 141 reviews..    (11 + 1) / 12]
# 2025-04-09 18:49:42,097 - INFO - Completed benchmark with target partition count 12:
# 2025-04-09 18:49:42,099 - INFO -   Total reviews: 1686
# 2025-04-09 18:49:42,099 - INFO -   Actual partitions: 12
# 2025-04-09 18:49:42,100 - INFO -   Process Time: 83.34 seconds
# 2025-04-09 18:49:42,101 - INFO -   Total Time: 83.47 seconds
# 2025-04-09 18:49:42,102 - INFO -   Processing Throughput: 20.23 reviews/second
# 2025-04-09 18:49:42,102 - INFO - Testing with target partition count of 16...
# 2025-04-09 18:49:42,103 - INFO - Using 16 partitions
# 2025-04-09 18:49:42,321 - INFO - Processing 105 reviews...
# 2025-04-09 18:49:42,322 - INFO - Processing 105 reviews...
# 2025-04-09 18:49:42,356 - INFO - Processing 105 reviews...
# 2025-04-09 18:49:42,357 - INFO - Processing 105 reviews...
# 2025-04-09 18:50:02,571 - INFO - Done processing 105 reviews..     (0 + 4) / 16]
# 2025-04-09 18:50:02,714 - INFO - Processing 107 reviews...
# 2025-04-09 18:50:02,805 - INFO - Done processing 105 reviews..
# 2025-04-09 18:50:02,935 - INFO - Done processing 105 reviews..     (1 + 4) / 16]
# 2025-04-09 18:50:02,970 - INFO - Processing 106 reviews...
# 2025-04-09 18:50:03,114 - INFO - Processing 106 reviews...         (2 + 4) / 16]
# 2025-04-09 18:50:03,192 - INFO - Done processing 105 reviews..
# 2025-04-09 18:50:03,310 - INFO - Processing 106 reviews...         (3 + 4) / 16]
# 2025-04-09 18:50:23,020 - INFO - Done processing 106 reviews..     (4 + 4) / 16]
# 2025-04-09 18:50:23,155 - INFO - Processing 106 reviews...
# 2025-04-09 18:50:23,534 - INFO - Done processing 106 reviews..     (5 + 4) / 16]
# 2025-04-09 18:50:23,574 - INFO - Done processing 107 reviews..
# 2025-04-09 18:50:23,646 - INFO - Processing 106 reviews...         (6 + 4) / 16]
# 2025-04-09 18:50:23,698 - INFO - Processing 106 reviews...
# 2025-04-09 18:50:23,882 - INFO - Done processing 106 reviews..     (7 + 4) / 16]
# 2025-04-09 18:50:23,990 - INFO - Processing 105 reviews...
# 2025-04-09 18:50:43,412 - INFO - Done processing 106 reviews..     (8 + 4) / 16]
# 2025-04-09 18:50:43,539 - INFO - Processing 105 reviews...
# 2025-04-09 18:50:44,179 - INFO - Done processing 106 reviews..     (9 + 4) / 16]
# 2025-04-09 18:50:44,281 - INFO - Processing 105 reviews...
# 2025-04-09 18:50:44,417 - INFO - Done processing 106 reviews..
# 2025-04-09 18:50:44,492 - INFO - Done processing 105 reviews..    (10 + 4) / 16]
# 2025-04-09 18:50:44,541 - INFO - Processing 104 reviews...
# 2025-04-09 18:50:44,612 - INFO - Processing 104 reviews...
# 2025-04-09 18:51:03,597 - INFO - Done processing 105 reviews..    (12 + 4) / 16]
# 2025-04-09 18:51:04,619 - INFO - Done processing 105 reviews..    (13 + 3) / 16]
# 2025-04-09 18:51:04,738 - INFO - Done processing 104 reviews..
# 2025-04-09 18:51:04,949 - INFO - Done processing 104 reviews..>   (15 + 1) / 16]
# 2025-04-09 18:51:05,265 - INFO - Completed benchmark with target partition count 16:
# 2025-04-09 18:51:05,267 - INFO -   Total reviews: 1686
# 2025-04-09 18:51:05,269 - INFO -   Actual partitions: 16
# 2025-04-09 18:51:05,270 - INFO -   Process Time: 82.99 seconds
# 2025-04-09 18:51:05,272 - INFO -   Total Time: 83.10 seconds
# 2025-04-09 18:51:05,275 - INFO -   Processing Throughput: 20.32 reviews/second
# 2025-04-09 18:51:05,277 - INFO - Testing with target partition count of 32...
# 2025-04-09 18:51:05,279 - INFO - Using 32 partitions
# 2025-04-09 18:51:05,515 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:05,519 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:05,521 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:05,549 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:15,582 - INFO - Done processing 53 reviews..      (0 + 4) / 32]
# 2025-04-09 18:51:15,617 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:15,711 - INFO - Processing 53 reviews...          (1 + 4) / 32]
# 2025-04-09 18:51:15,740 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:15,794 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:15,799 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:15,889 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:15,900 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:26,007 - INFO - Done processing 53 reviews..      (4 + 4) / 32]
# 2025-04-09 18:51:26,043 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:26,162 - INFO - Processing 54 reviews...
# 2025-04-09 18:51:26,170 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:26,177 - INFO - Processing 55 reviews...
# 2025-04-09 18:51:26,283 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:26,469 - INFO - Done processing 53 reviews..      (7 + 4) / 32]
# 2025-04-09 18:51:26,573 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:36,564 - INFO - Done processing 53 reviews..      (8 + 4) / 32]
# 2025-04-09 18:51:36,579 - INFO - Done processing 54 reviews..
# 2025-04-09 18:51:36,685 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:36,717 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:36,807 - INFO - Done processing 55 reviews..     (10 + 4) / 32]
# 2025-04-09 18:51:36,950 - INFO - Processing 53 reviews...         (11 + 4) / 32]
# 2025-04-09 18:51:36,965 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:37,101 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:46,744 - INFO - Done processing 53 reviews..     (12 + 4) / 32]
# 2025-04-09 18:51:46,881 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:47,106 - INFO - Done processing 53 reviews..     (13 + 4) / 32]
# 2025-04-09 18:51:47,197 - INFO - Processing 53 reviews...
# 2025-04-09 18:51:47,273 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:47,281 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:47,386 - INFO - Processing 52 reviews...         (14 + 4) / 32]
# 2025-04-09 18:51:47,429 - INFO - Processing 52 reviews...
# 2025-04-09 18:51:57,370 - INFO - Done processing 52 reviews..     (16 + 4) / 32]
# 2025-04-09 18:51:57,394 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:57,414 - INFO - Done processing 53 reviews..
# 2025-04-09 18:51:57,487 - INFO - Processing 52 reviews...
# 2025-04-09 18:51:57,517 - INFO - Processing 52 reviews...
# 2025-04-09 18:51:57,566 - INFO - Processing 52 reviews...         (19 + 4) / 32]
# 2025-04-09 18:51:57,609 - INFO - Done processing 52 reviews..
# 2025-04-09 18:51:57,704 - INFO - Processing 52 reviews...
# 2025-04-09 18:52:07,602 - INFO - Done processing 52 reviews..     (20 + 4) / 32]
# 2025-04-09 18:52:07,684 - INFO - Done processing 52 reviews..
# 2025-04-09 18:52:07,695 - INFO - Processing 52 reviews...
# 2025-04-09 18:52:07,821 - INFO - Processing 52 reviews...         (21 + 4) / 32]
# 2025-04-09 18:52:07,848 - INFO - Done processing 52 reviews..
# 2025-04-09 18:52:07,990 - INFO - Processing 52 reviews...         (23 + 4) / 32]
# 2025-04-09 18:52:08,134 - INFO - Done processing 52 reviews..
# 2025-04-09 18:52:08,260 - INFO - Processing 52 reviews...
# 2025-04-09 18:52:17,751 - INFO - Done processing 52 reviews..     (24 + 4) / 32]
# 2025-04-09 18:52:17,875 - INFO - Processing 52 reviews...
# 2025-04-09 18:52:18,013 - INFO - Done processing 52 reviews..     (25 + 4) / 32]
# 2025-04-09 18:52:18,110 - INFO - Processing 52 reviews...
# 2025-04-09 18:52:18,119 - INFO - Done processing 52 reviews..
# 2025-04-09 18:52:18,246 - INFO - Processing 52 reviews...         (26 + 4) / 32]
# 2025-04-09 18:52:18,386 - INFO - Done processing 52 reviews..     (27 + 4) / 32]
# 2025-04-09 18:52:18,497 - INFO - Processing 53 reviews...
# 2025-04-09 18:52:27,897 - INFO - Done processing 52 reviews..     (28 + 4) / 32]
# 2025-04-09 18:52:28,147 - INFO - Done processing 52 reviews..
# 2025-04-09 18:52:28,425 - INFO - Done processing 52 reviews..=>   (30 + 2) / 32]
# 2025-04-09 18:52:28,715 - INFO - Done processing 53 reviews..===> (31 + 1) / 32]
# 2025-04-09 18:52:29,056 - INFO - Completed benchmark with target partition count 32:
# 2025-04-09 18:52:29,057 - INFO -   Total reviews: 1686
# 2025-04-09 18:52:29,057 - INFO -   Actual partitions: 32
# 2025-04-09 18:52:29,058 - INFO -   Process Time: 83.59 seconds
# 2025-04-09 18:52:29,059 - INFO -   Total Time: 83.72 seconds
# 2025-04-09 18:52:29,060 - INFO -   Processing Throughput: 20.17 reviews/second
# 2025-04-09 18:52:29,061 - INFO - Testing with target partition count of 64...
# 2025-04-09 18:52:29,061 - INFO - Using 64 partitions
# 2025-04-09 18:52:29,324 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:29,343 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:29,354 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:29,388 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:34,426 - INFO - Done processing 26 reviews..      (0 + 4) / 64]
# 2025-04-09 18:52:34,462 - INFO - Done processing 26 reviews..
# 2025-04-09 18:52:34,517 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:34,534 - INFO - Done processing 26 reviews..
# 2025-04-09 18:52:34,578 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:34,671 - INFO - Processing 26 reviews...          (2 + 4) / 64]
# 2025-04-09 18:52:34,965 - INFO - Done processing 26 reviews..      (3 + 4) / 64]
# 2025-04-09 18:52:35,083 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:39,602 - INFO - Done processing 26 reviews..      (4 + 4) / 64]
# 2025-04-09 18:52:39,703 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:39,761 - INFO - Done processing 26 reviews..
# 2025-04-09 18:52:39,856 - INFO - Done processing 26 reviews..      (5 + 4) / 64]
# 2025-04-09 18:52:39,865 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:39,941 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:40,318 - INFO - Done processing 26 reviews..      (7 + 4) / 64]
# 2025-04-09 18:52:40,442 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:44,870 - INFO - Done processing 26 reviews..      (8 + 4) / 64]
# 2025-04-09 18:52:44,980 - INFO - Done processing 26 reviews..
# 2025-04-09 18:52:45,001 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:45,062 - INFO - Done processing 26 reviews..      (9 + 4) / 64]
# 2025-04-09 18:52:45,138 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:45,208 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:45,512 - INFO - Done processing 26 reviews..     (11 + 4) / 64]
# 2025-04-09 18:52:45,628 - INFO - Processing 26 reviews...
# 2025-04-09 18:52:50,131 - INFO - Done processing 26 reviews..     (12 + 4) / 64]
# 2025-04-09 18:52:50,252 - INFO - Processing 28 reviews...
# 2025-04-09 18:52:50,272 - INFO - Done processing 26 reviews..
# 2025-04-09 18:52:50,373 - INFO - Done processing 26 reviews..
# 2025-04-09 18:52:50,387 - INFO - Processing 27 reviews...
# 2025-04-09 18:52:50,511 - INFO - Processing 27 reviews...         (14 + 4) / 64]
# 2025-04-09 18:52:50,848 - INFO - Done processing 26 reviews..     (15 + 4) / 64]
# 2025-04-09 18:52:50,956 - INFO - Processing 27 reviews...
# 2025-04-09 18:52:55,641 - INFO - Done processing 27 reviews..     (16 + 4) / 64]
# 2025-04-09 18:52:55,744 - INFO - Processing 27 reviews...
# 2025-04-09 18:52:55,790 - INFO - Done processing 28 reviews..
# 2025-04-09 18:52:55,864 - INFO - Done processing 27 reviews..     (17 + 4) / 64]
# 2025-04-09 18:52:55,901 - INFO - Processing 27 reviews...
# 2025-04-09 18:52:56,030 - INFO - Processing 27 reviews...
# 2025-04-09 18:52:56,313 - INFO - Done processing 27 reviews..     (19 + 4) / 64]
# 2025-04-09 18:52:56,432 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:01,114 - INFO - Done processing 27 reviews..     (20 + 4) / 64]
# 2025-04-09 18:53:01,195 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:01,228 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:01,329 - INFO - Processing 27 reviews...         (21 + 4) / 64]
# 2025-04-09 18:53:01,671 - INFO - Done processing 27 reviews..     (22 + 4) / 64]
# 2025-04-09 18:53:01,675 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:01,797 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:01,798 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:06,517 - INFO - Done processing 27 reviews..     (24 + 4) / 64]
# 2025-04-09 18:53:06,520 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:06,621 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:06,622 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:07,004 - INFO - Done processing 27 reviews..     (26 + 4) / 64]
# 2025-04-09 18:53:07,138 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:07,138 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:07,283 - INFO - Processing 27 reviews...         (27 + 4) / 64]
# 2025-04-09 18:53:11,890 - INFO - Done processing 27 reviews..     (28 + 4) / 64]
# 2025-04-09 18:53:11,911 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:11,997 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:12,044 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:12,409 - INFO - Done processing 27 reviews..     (30 + 4) / 64]
# 2025-04-09 18:53:12,509 - INFO - Processing 27 reviews...         (31 + 4) / 64]
# 2025-04-09 18:53:12,699 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:12,829 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:17,207 - INFO - Done processing 27 reviews..     (32 + 4) / 64]
# 2025-04-09 18:53:17,318 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:17,327 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:17,439 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:17,773 - INFO - Done processing 27 reviews..     (34 + 4) / 64]
# 2025-04-09 18:53:17,888 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:18,256 - INFO - Done processing 27 reviews..     (35 + 4) / 64]
# 2025-04-09 18:53:18,368 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:22,603 - INFO - Done processing 27 reviews..     (36 + 4) / 64]
# 2025-04-09 18:53:22,729 - INFO - Processing 27 reviews...
# 2025-04-09 18:53:22,756 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:22,923 - INFO - Processing 26 reviews...         (38 + 4) / 64]
# 2025-04-09 18:53:23,387 - INFO - Done processing 27 reviews..
# 2025-04-09 18:53:23,501 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:23,770 - INFO - Done processing 27 reviews..     (39 + 4) / 64]
# 2025-04-09 18:53:23,895 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:27,910 - INFO - Done processing 27 reviews..     (40 + 4) / 64]
# 2025-04-09 18:53:28,025 - INFO - Done processing 26 reviews..
# 2025-04-09 18:53:28,033 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:28,137 - INFO - Processing 26 reviews...         (41 + 4) / 64]
# 2025-04-09 18:53:28,605 - INFO - Done processing 26 reviews..     (42 + 4) / 64]
# 2025-04-09 18:53:28,734 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:29,026 - INFO - Done processing 26 reviews..     (43 + 4) / 64]
# 2025-04-09 18:53:29,151 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:33,111 - INFO - Done processing 26 reviews..     (44 + 4) / 64]
# 2025-04-09 18:53:33,129 - INFO - Done processing 26 reviews..
# 2025-04-09 18:53:33,239 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:33,255 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:33,824 - INFO - Done processing 26 reviews..     (46 + 4) / 64]
# 2025-04-09 18:53:33,928 - INFO - Processing 26 reviews...         (47 + 4) / 64]
# 2025-04-09 18:53:34,301 - INFO - Done processing 26 reviews..
# 2025-04-09 18:53:34,411 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:38,247 - INFO - Done processing 26 reviews..     (48 + 4) / 64]
# 2025-04-09 18:53:38,254 - INFO - Done processing 26 reviews..
# 2025-04-09 18:53:38,350 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:38,381 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:39,032 - INFO - Done processing 26 reviews..     (50 + 4) / 64]
# 2025-04-09 18:53:39,132 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:39,592 - INFO - Done processing 26 reviews..     (51 + 4) / 64]
# 2025-04-09 18:53:39,692 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:43,373 - INFO - Done processing 26 reviews..     (52 + 4) / 64]
# 2025-04-09 18:53:43,486 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:43,653 - INFO - Done processing 26 reviews..     (53 + 4) / 64]
# 2025-04-09 18:53:43,779 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:44,121 - INFO - Done processing 26 reviews..     (54 + 4) / 64]
# 2025-04-09 18:53:44,240 - INFO - Processing 25 reviews...
# 2025-04-09 18:53:44,847 - INFO - Done processing 26 reviews..     (55 + 4) / 64]
# 2025-04-09 18:53:44,982 - INFO - Processing 25 reviews...
# 2025-04-09 18:53:48,553 - INFO - Done processing 26 reviews..     (56 + 4) / 64]
# 2025-04-09 18:53:48,660 - INFO - Processing 25 reviews...
# 2025-04-09 18:53:48,934 - INFO - Done processing 26 reviews..     (57 + 4) / 64]
# 2025-04-09 18:53:49,036 - INFO - Processing 25 reviews...
# 2025-04-09 18:53:49,159 - INFO - Done processing 25 reviews..     (58 + 4) / 64]
# 2025-04-09 18:53:49,263 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:50,535 - INFO - Done processing 25 reviews..>    (59 + 4) / 64]
# 2025-04-09 18:53:50,647 - INFO - Processing 26 reviews...
# 2025-04-09 18:53:53,639 - INFO - Done processing 25 reviews..=>   (60 + 4) / 64]
# 2025-04-09 18:53:54,129 - INFO - Done processing 25 reviews..==>  (61 + 3) / 64]
# 2025-04-09 18:53:54,486 - INFO - Done processing 26 reviews..===> (62 + 2) / 64]
# 2025-04-09 18:53:55,626 - INFO - Done processing 26 reviews..====>(63 + 1) / 64]
# 2025-04-09 18:53:56,348 - INFO - Completed benchmark with target partition count 64:
# 2025-04-09 18:53:56,350 - INFO -   Total reviews: 1686
# 2025-04-09 18:53:56,351 - INFO -   Actual partitions: 64
# 2025-04-09 18:53:56,353 - INFO -   Process Time: 87.07 seconds
# 2025-04-09 18:53:56,354 - INFO -   Total Time: 87.21 seconds
# 2025-04-09 18:53:56,355 - INFO -   Processing Throughput: 19.36 reviews/second
# 2025-04-09 18:53:56,357 - INFO - Testing with target partition count of 128...
# 2025-04-09 18:53:56,358 - INFO - Using 128 partitions
# 2025-04-09 18:53:56,831 - INFO - Processing 13 reviews...
# 2025-04-09 18:53:56,853 - INFO - Processing 13 reviews...
# 2025-04-09 18:53:56,880 - INFO - Processing 13 reviews...
# 2025-04-09 18:53:56,885 - INFO - Processing 13 reviews...
# 2025-04-09 18:53:59,820 - INFO - Done processing 13 reviews..     (0 + 4) / 128]
# 2025-04-09 18:53:59,835 - INFO - Done processing 13 reviews..
# 2025-04-09 18:53:59,894 - INFO - Done processing 13 reviews..
# 2025-04-09 18:53:59,936 - INFO - Processing 13 reviews...
# 2025-04-09 18:53:59,970 - INFO - Processing 13 reviews...
# 2025-04-09 18:53:59,989 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:00,072 - INFO - Done processing 13 reviews..     (3 + 4) / 128]
# 2025-04-09 18:54:00,184 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:02,563 - INFO - Done processing 13 reviews..     (4 + 4) / 128]
# 2025-04-09 18:54:02,580 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:02,615 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:02,688 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:02,703 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:02,752 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:02,820 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:02,918 - INFO - Processing 13 reviews...         (7 + 4) / 128]
# 2025-04-09 18:54:05,185 - INFO - Done processing 13 reviews..     (8 + 4) / 128]
# 2025-04-09 18:54:05,286 - INFO - Processing 13 reviews...         (9 + 4) / 128]
# 2025-04-09 18:54:05,316 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:05,338 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:05,428 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:05,430 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:05,525 - INFO - Done processing 13 reviews..    (11 + 4) / 128]
# 2025-04-09 18:54:05,657 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:07,878 - INFO - Done processing 13 reviews..    (12 + 4) / 128]
# 2025-04-09 18:54:07,951 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:07,985 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:08,009 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:08,129 - INFO - Processing 13 reviews...        (13 + 4) / 128]
# 2025-04-09 18:54:08,147 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:08,177 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:08,330 - INFO - Processing 13 reviews...        (15 + 4) / 128]
# 2025-04-09 18:54:10,561 - INFO - Done processing 13 reviews..    (16 + 4) / 128]
# 2025-04-09 18:54:10,661 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:10,703 - INFO - Done processing 13 reviews..    (17 + 4) / 128]
# 2025-04-09 18:54:10,744 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:10,828 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:10,916 - INFO - Processing 13 reviews...        (19 + 4) / 128]
# 2025-04-09 18:54:11,076 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:11,186 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:13,227 - INFO - Done processing 13 reviews..    (20 + 4) / 128]
# 2025-04-09 18:54:13,322 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:13,369 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:13,449 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:13,536 - INFO - Done processing 13 reviews..    (22 + 4) / 128]
# 2025-04-09 18:54:13,655 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:13,790 - INFO - Done processing 13 reviews..    (23 + 4) / 128]
# 2025-04-09 18:54:13,893 - INFO - Processing 13 reviews...        (24 + 4) / 128]
# 2025-04-09 18:54:15,982 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:16,036 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:16,112 - INFO - Processing 13 reviews...        (25 + 4) / 128]
# 2025-04-09 18:54:16,161 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:16,363 - INFO - Done processing 13 reviews..    (26 + 4) / 128]
# 2025-04-09 18:54:16,423 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:16,485 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:16,531 - INFO - Processing 14 reviews...        (27 + 4) / 128]
# 2025-04-09 18:54:18,665 - INFO - Done processing 13 reviews..    (28 + 4) / 128]
# 2025-04-09 18:54:18,712 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:18,770 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:18,819 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:19,031 - INFO - Done processing 13 reviews..    (30 + 4) / 128]
# 2025-04-09 18:54:19,130 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:19,292 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:19,392 - INFO - Processing 14 reviews...        (31 + 4) / 128]
# 2025-04-09 18:54:21,550 - INFO - Done processing 14 reviews..    (32 + 4) / 128]
# 2025-04-09 18:54:21,628 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:21,851 - INFO - Done processing 14 reviews..    (33 + 4) / 128]
# 2025-04-09 18:54:21,908 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:21,975 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:22,051 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:22,213 - INFO - Done processing 14 reviews..    (35 + 4) / 128]
# 2025-04-09 18:54:22,296 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:24,367 - INFO - Done processing 14 reviews..    (36 + 4) / 128]
# 2025-04-09 18:54:24,497 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:24,769 - INFO - Done processing 14 reviews..    (37 + 4) / 128]
# 2025-04-09 18:54:24,831 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:24,891 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:24,931 - INFO - Processing 14 reviews...        (38 + 4) / 128]
# 2025-04-09 18:54:25,017 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:25,133 - INFO - Processing 14 reviews...        (39 + 4) / 128]
# 2025-04-09 18:54:27,349 - INFO - Done processing 14 reviews..    (40 + 4) / 128]
# 2025-04-09 18:54:27,443 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:27,708 - INFO - Done processing 14 reviews..    (41 + 4) / 128]
# 2025-04-09 18:54:27,811 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:27,843 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:27,876 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:27,966 - INFO - Processing 14 reviews...        (42 + 4) / 128]
# 2025-04-09 18:54:27,981 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:30,292 - INFO - Done processing 14 reviews..    (44 + 4) / 128]
# 2025-04-09 18:54:30,425 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:30,616 - INFO - Done processing 14 reviews..    (45 + 4) / 128]
# 2025-04-09 18:54:30,710 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:30,748 - INFO - Processing 14 reviews...        (46 + 4) / 128]
# 2025-04-09 18:54:30,805 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:30,832 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:30,939 - INFO - Processing 14 reviews...        (48 + 4) / 128]
# 2025-04-09 18:54:33,279 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:33,364 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:33,618 - INFO - Done processing 14 reviews..    (49 + 4) / 128]
# 2025-04-09 18:54:33,652 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:33,724 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:33,756 - INFO - Processing 14 reviews...        (50 + 4) / 128]
# 2025-04-09 18:54:33,875 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:33,991 - INFO - Processing 14 reviews...        (51 + 4) / 128]
# 2025-04-09 18:54:36,295 - INFO - Done processing 14 reviews..    (52 + 4) / 128]
# 2025-04-09 18:54:36,395 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:36,474 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:36,490 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:36,577 - INFO - Processing 14 reviews...        (53 + 4) / 128]
# 2025-04-09 18:54:36,607 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:36,942 - INFO - Done processing 14 reviews..    (55 + 4) / 128]
# 2025-04-09 18:54:37,040 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:39,179 - INFO - Done processing 14 reviews..    (56 + 4) / 128]
# 2025-04-09 18:54:39,255 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:39,345 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:39,455 - INFO - Processing 14 reviews...        (57 + 4) / 128]
# 2025-04-09 18:54:39,629 - INFO - Done processing 14 reviews..    (58 + 4) / 128]
# 2025-04-09 18:54:39,739 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:39,863 - INFO - Done processing 14 reviews..    (59 + 4) / 128]
# 2025-04-09 18:54:39,957 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:42,136 - INFO - Done processing 14 reviews..    (60 + 4) / 128]
# 2025-04-09 18:54:42,254 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:42,353 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:42,472 - INFO - Processing 14 reviews...        (61 + 4) / 128]
# 2025-04-09 18:54:42,659 - INFO - Done processing 14 reviews..    (62 + 4) / 128]
# 2025-04-09 18:54:42,779 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:42,781 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:42,948 - INFO - Processing 14 reviews...        (63 + 4) / 128]
# 2025-04-09 18:54:45,093 - INFO - Done processing 14 reviews..    (64 + 4) / 128]
# 2025-04-09 18:54:45,197 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:45,285 - INFO - Done processing 14 reviews..    (65 + 4) / 128]
# 2025-04-09 18:54:45,401 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:45,595 - INFO - Done processing 14 reviews..    (66 + 4) / 128]
# 2025-04-09 18:54:45,643 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:45,683 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:45,766 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:48,174 - INFO - Done processing 14 reviews..    (68 + 4) / 128]
# 2025-04-09 18:54:48,230 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:48,301 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:48,386 - INFO - Processing 14 reviews...
# 2025-04-09 18:54:48,514 - INFO - Done processing 14 reviews..    (70 + 4) / 128]
# 2025-04-09 18:54:48,572 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:48,624 - INFO - Processing 13 reviews...        (71 + 4) / 128]
# 2025-04-09 18:54:48,693 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:51,080 - INFO - Done processing 14 reviews..    (72 + 4) / 128]
# 2025-04-09 18:54:51,149 - INFO - Done processing 14 reviews..
# 2025-04-09 18:54:51,171 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:51,178 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:51,247 - INFO - Done processing 13 reviews..    (74 + 4) / 128]
# 2025-04-09 18:54:51,265 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:51,305 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:51,400 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:53,678 - INFO - Done processing 13 reviews..    (76 + 4) / 128]
# 2025-04-09 18:54:53,706 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:53,782 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:53,799 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:53,801 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:53,918 - INFO - Processing 13 reviews...        (78 + 4) / 128]
# 2025-04-09 18:54:53,956 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:54,087 - INFO - Processing 13 reviews...        (79 + 4) / 128]
# 2025-04-09 18:54:56,285 - INFO - Done processing 13 reviews..    (80 + 4) / 128]
# 2025-04-09 18:54:56,383 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:56,429 - INFO - Done processing 13 reviews..    (81 + 4) / 128]
# 2025-04-09 18:54:56,492 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:56,555 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:56,574 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:56,671 - INFO - Done processing 13 reviews..    (83 + 4) / 128]
# 2025-04-09 18:54:56,786 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:58,931 - INFO - Done processing 13 reviews..    (84 + 4) / 128]
# 2025-04-09 18:54:59,055 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:59,121 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:59,138 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:59,238 - INFO - Processing 13 reviews...        (87 + 4) / 128]
# 2025-04-09 18:54:59,251 - INFO - Processing 13 reviews...
# 2025-04-09 18:54:59,402 - INFO - Done processing 13 reviews..
# 2025-04-09 18:54:59,490 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:01,711 - INFO - Done processing 13 reviews..    (88 + 4) / 128]
# 2025-04-09 18:55:01,827 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:01,849 - INFO - Done processing 13 reviews..    (89 + 4) / 128]
# 2025-04-09 18:55:01,860 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:01,973 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:01,995 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:02,169 - INFO - Done processing 13 reviews..    (91 + 4) / 128]
# 2025-04-09 18:55:02,291 - INFO - Processing 13 reviews...        (91 + 5) / 128]
# 2025-04-09 18:55:04,442 - INFO - Done processing 13 reviews..    (92 + 4) / 128]
# 2025-04-09 18:55:04,502 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:04,545 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:04,617 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:04,715 - INFO - Done processing 13 reviews..    (94 + 4) / 128]
# 2025-04-09 18:55:04,840 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:04,842 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:04,992 - INFO - Processing 13 reviews...        (95 + 4) / 128]
# 2025-04-09 18:55:07,194 - INFO - Done processing 13 reviews..    (96 + 4) / 128]
# 2025-04-09 18:55:07,202 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:07,286 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:07,308 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:07,360 - INFO - Done processing 13 reviews..    (98 + 4) / 128]
# 2025-04-09 18:55:07,497 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:07,558 - INFO - Done processing 13 reviews..    (99 + 4) / 128]
# 2025-04-09 18:55:07,673 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:09,839 - INFO - Done processing 13 reviews..   (100 + 4) / 128]
# 2025-04-09 18:55:09,906 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:09,940 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:09,963 - INFO - Processing 12 reviews...       (101 + 4) / 128]
# 2025-04-09 18:55:10,005 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:10,053 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:10,094 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:10,201 - INFO - Processing 12 reviews...       (103 + 4) / 128]
# 2025-04-09 18:55:12,324 - INFO - Done processing 12 reviews..   (104 + 4) / 128]
# 2025-04-09 18:55:12,395 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:12,424 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:12,446 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:12,524 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:12,556 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:12,646 - INFO - Done processing 12 reviews..   (107 + 4) / 128]
# 2025-04-09 18:55:12,752 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:14,745 - INFO - Done processing 12 reviews..   (108 + 4) / 128]
# 2025-04-09 18:55:14,832 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:14,868 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:14,969 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:14,994 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:15,061 - INFO - Done processing 12 reviews..   (110 + 4) / 128]
# 2025-04-09 18:55:15,101 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:15,151 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:17,212 - INFO - Done processing 12 reviews..   (112 + 4) / 128]
# 2025-04-09 18:55:17,305 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:17,326 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:17,417 - INFO - Processing 12 reviews...>      (113 + 4) / 128]
# 2025-04-09 18:55:17,456 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:17,538 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:17,606 - INFO - Done processing 12 reviews..   (115 + 4) / 128]
# 2025-04-09 18:55:17,712 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:19,679 - INFO - Done processing 12 reviews..   (116 + 4) / 128]
# 2025-04-09 18:55:19,770 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:19,798 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:19,912 - INFO - Processing 12 reviews...==>    (117 + 4) / 128]
# 2025-04-09 18:55:20,037 - INFO - Done processing 12 reviews..   (118 + 4) / 128]
# 2025-04-09 18:55:20,074 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:20,156 - INFO - Processing 12 reviews...
# 2025-04-09 18:55:20,236 - INFO - Processing 13 reviews...===>   (120 + 4) / 128]
# 2025-04-09 18:55:22,164 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:22,246 - INFO - Done processing 12 reviews..
# 2025-04-09 18:55:22,289 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:22,368 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:22,552 - INFO - Done processing 12 reviews..>  (122 + 4) / 128]
# 2025-04-09 18:55:22,684 - INFO - Processing 13 reviews...
# 2025-04-09 18:55:22,770 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:22,895 - INFO - Processing 13 reviews...====>  (123 + 4) / 128]
# 2025-04-09 18:55:24,896 - INFO - Done processing 13 reviews..=> (124 + 4) / 128]
# 2025-04-09 18:55:24,930 - INFO - Done processing 13 reviews..
# 2025-04-09 18:55:25,339 - INFO - Done processing 13 reviews..==>(126 + 2) / 128]
# 2025-04-09 18:55:25,422 - INFO - Done processing 13 reviews..==>(127 + 1) / 128]
# 2025-04-09 18:55:26,716 - INFO - Completed benchmark with target partition count 128:
# 2025-04-09 18:55:26,717 - INFO -   Total reviews: 1686
# 2025-04-09 18:55:26,717 - INFO -   Actual partitions: 128
# 2025-04-09 18:55:26,718 - INFO -   Process Time: 89.98 seconds
# 2025-04-09 18:55:26,719 - INFO -   Total Time: 90.28 seconds
# 2025-04-09 18:55:26,720 - INFO -   Processing Throughput: 18.74 reviews/second

# %%
output_dir = os.getcwd()
Path(output_dir).mkdir(parents=True, exist_ok=True)
results_df = pd.DataFrame(results)
results_df.to_csv(f"{output_dir}/partition_count_benchmark_results.csv", index=False)

# Create a summary report
with open(f"{output_dir}/partition_count_benchmark_summary.txt", 'w') as f:
    f.write("Spark Partition Count Benchmark Summary\n")
    f.write("=====================================\n\n")
    
    # Find optimal partition size based on throughput
    optimal_idx = results_df['throughput'].idxmax()
    optimal_partitions = results_df.iloc[optimal_idx]['target_num_partitions']
    
    f.write(f"Total reviews processed: {results_df.iloc[0]['total_reviews']}\n")
    f.write(f"Optimal target partition size: {optimal_size} MB\n")
    f.write(f"Optimal number of partitions: {optimal_partitions}\n\n")
    
    f.write("Detailed Results:\n")
    f.write("-----------------\n")
    for _, row in results_df.iterrows():
        f.write(f"Target Partition Count: {row['target_num_partitions']} MB\n")
        f.write(f"  Actual Partitions: {int(row['actual_partitions'])}\n")
        f.write(f"  Reviews per partition: {int(row['reviews_per_partition'])}\n")
        f.write(f"  Process Time: {row['process_time']:.2f} seconds\n")
        f.write(f"  Total Time: {row['total_time']:.2f} seconds\n")
        f.write(f"  Throughput: {row['throughput']:.2f} reviews/second\n\n")

# %%
results_df
# Out:
#     target_num_partitions  actual_partitions  reviews_per_partition  \
# 0                       2                  2             843.000000
# 1                       3                  3             562.000000
# 2                       4                  4             421.500000
# 3                       6                  6             281.000000
# 4                       8                  8             210.750000
# 5                      10                 10             168.600000
# 6                      12                 12             140.500000
# 7                      16                 16             105.375000
# 8                      32                 32              52.687500
# 9                      64                 64              26.343750
# 10                    128                128              13.171875
#
#     total_reviews  result_count  process_time  total_time  throughput
# 0            1686          1686    165.594337  165.708975   10.181508
# 1            1686          1686    113.792464  113.866739   14.816447
# 2            1686          1686     87.004179   87.084807   19.378379
# 3            1686          1686    106.323035  106.434450   15.857335
# 4            1686          1686     84.050362   84.152804   20.059402
# 5            1686          1686     97.293380   97.384135   17.329031
# 6            1686          1686     83.341282   83.471644   20.230070
# 7            1686          1686     82.990737   83.100753   20.315520
# 8            1686          1686     83.588270   83.716780   20.170294
# 9            1686          1686     87.067641   87.213753   19.364255
# 10           1686          1686     89.976614   90.281903   18.738202

# %%
# Create output directory if it doesn't exist
output_dir = os.getcwd()
Path(output_dir).mkdir(parents=True, exist_ok=True)

# Set style
plt.style.use('ggplot')

# Figure 1: Total Time vs Partition Count
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_num_partitions'], results_df['total_time'], 'o-', linewidth=2)
plt.title('Total Execution Time vs Partition Count')
plt.xlabel('Target Partition Count')
plt.ylabel('Time (seconds)')
plt.xscale('log', base=2)  # Use logarithmic scale with base 2
plt.xticks(results_df['target_num_partitions'], labels=results_df['target_num_partitions'])  # Keep original tick values
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/total_time_vs_partition_count.png")

# Figure 2: Process Time vs Partition Count
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_num_partitions'], results_df['process_time'], 'o-', linewidth=2)
plt.title('Processing Time vs Partition Count')
plt.xlabel('Target Partition Count')
plt.ylabel('Time (seconds)')
plt.xscale('log', base=2)  # Use logarithmic scale with base 2
plt.xticks(results_df['target_num_partitions'], labels=results_df['target_num_partitions'])  # Keep original tick values
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/process_time_vs_partition_count.png")

# Figure 3: Throughput vs Partition Count
plt.figure(figsize=(10, 6))
plt.plot(results_df['target_num_partitions'], results_df['throughput'], 'o-', linewidth=2)
plt.title('Throughput vs Partition Count')
plt.xlabel('Target Partition Count')
plt.ylabel('Throughput (reviews/second)')
plt.xscale('log', base=2)  # Use logarithmic scale with base 2
plt.xticks(results_df['target_num_partitions'], labels=results_df['target_num_partitions'])  # Keep original tick values
plt.grid(True)
plt.tight_layout()
plt.savefig(f"{output_dir}/throughput_vs_partition_count.png")

# Figure 4: Time Breakdown
plt.figure(figsize=(12, 6))
width = 0.35
ind = np.arange(len(results_df))
plt.bar(ind, results_df['process_time'], width, label='Process Time')
plt.xlabel('Target Partition Count')
plt.ylabel('Time (seconds)')
plt.title('Time Breakdown by Partition Count')
plt.xticks(ind, results_df['target_num_partitions'])  # Keep the original ticks for the bar chart
plt.legend()
plt.tight_layout()
plt.savefig(f"{output_dir}/time_breakdown_partition_count.png")

plt.close('all')
